# %%
#---------------------------------------------------------------------------------
# #                    _            _    
#                   | |          | |   
#   ___  __ _ ______| | ___   ___| | __
#  / __|/ _` |_  / _` |/ _ \ / __| |/ /
#  \__ \ (_| |/ / (_| | (_) | (__|   < 
#  |___/\__,_/___\__,_|\___/ \___|_|\_\
#   tool for high-speed cloud molecular docking in colab                                  
#                                            
#                                                                                 
#**created by saz**                                       based on autodockvina 
#---------------------------------------------------------------------------------

# %% [markdown]
# #![sazdock.png](data:image/png;base64,...)
# https://drive.google.com/drive/folders/1XZZWpXMOwZubq5Fldy3SM9oogPWHuzSX?usp=sharing

# %% [markdown]
# ***Run the below cell to mount the google drive to colab Note: Use the account where you have uploaded your sazdock folder***

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#mount your folder in the drive
# !cd /content/drive/MyDrive/sazdock
# !apt-get install php libapache2-mod-php &> /dev/null
#docking help
# !php /content/drive/MyDrive/sazdock/dock.ini --help

# %% [markdown]
# **docking area** edit the name of the receptor **(protein.pdbqt)** below with the name of your receptor

# %%
 # !php /content/drive/MyDrive/sazdock/dock.ini --receptor protein.pdbqt --ligands ./ligands/ --config conf.txt --output results_output_file.txt
